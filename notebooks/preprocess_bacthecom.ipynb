# %% [markdown]
# ### Preprocessing database BactHeCom
# Preprocess and recode BactHeCom variables from xlsx

# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# paths
data_dir = '../data/'
dataset='datos_BactHeCom_HUVR_v2.xlsx'

# %%
# load dataset
db = pd.read_excel(os.path.join(data_dir, dataset), index_col=0)
db.head()
# Out:
#           fecha_ingreso fecha_alta  duracion_hospitalizacion fecha_nacimiento  \
# record_id
# 1            2021-08-24 2021-09-09                        16       1943-03-28
# 2            2023-06-18 2023-07-13                        25       1959-12-16
# 3            2022-02-11 2022-04-06                        54       1976-11-14
# 4            2021-05-15 2021-07-28                        74       1992-09-27
# 5            2021-07-04 2022-01-04                       184       1994-07-13
#
#            edad    sexo  codigo_postal  mujer_gestante  paciente_residencia  \
# record_id
# 1            78  Hombre           4007               0                  0.0
# 2            63   Mujer           4740               0                  0.0
# 3            45  Hombre           4700               0                  NaN
# 4            28  Hombre          18800               0                  0.0
# 5            26   Mujer          23009               0                  0.0
#
# ...

# %%
db.columns.values
# Out:
# array(['fecha_ingreso', 'fecha_alta', 'duracion_hospitalizacion',
#        'fecha_nacimiento', 'edad', 'sexo', 'codigo_postal',
#        'mujer_gestante', 'paciente_residencia', 'infarto',
#        'insuficiencia_cardiaca', 'evp', 'e_cerebrovascular', 'demencia',
#        'e_pulmonar_cronica', 'ulcera_peptica', 'colagenopatia',
#        'hemiplejia', 'erc', 'neoplasia_tratamiento_activo',
#        'neoplasia_solida_metastasica', 'neoplasia_solida_no_metastasica',
#        'tipo_cancer', 'linfoma', 'leucemia', 'sida', 'puntaje_child_pugh',
#        'hepatopatia_ligera', 'hepatopatia_moderada_o_grave',
#        'tipo_hepatopatia', 'diabetes', 'diabetes_sin_lesion_organo_diana',
#        'diabetes_con_lesion_organo_diana', 'inmunosupresion',
#        'causa_inmunosupresion', 'TOS', 'fecha_TOS', 'TPH', 'fecha_TPH',
#        'clasificacion_quemadura', 'gran_quemado',
#        'situacion_funcional_basal', 'indice_de_charlson',
# ...
