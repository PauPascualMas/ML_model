# %% [markdown]
# ## Dimensionality reduction
# This script aims to reduce the dimensionality of the dataset by filtering out missing or irrelevant variables for the model prediction

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
DATA_DIR = "../data"
RESULTS_DIR = "../results"

# %%
### Load merged df
